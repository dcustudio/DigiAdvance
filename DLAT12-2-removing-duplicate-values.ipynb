# %%
import pandas as pd

# read the data from a file using pandas. Notice that this is a new file.
data = pd.read_csv("DLAT-Sample-12-2-2.csv")

# The following code checks whether the transport column contains null value or not
data.head(15)
# Out:
#     Code    Name  County      City    Activity        Date Start Time  \
# 0      1  Jack F  Dublin  Dublin 9      Travel  07/07/2022       7;30
# 1      1  Jack F  Dublin  Dublin 9     Lecture  07/07/2022      09:00
# 2      1  Jack F  Dublin  Dublin 9     Lecture  07/07/2022      11:00
# 3      1  Jack F  Dublin  Dublin 9       Study  07/07/2022      01:00
# 4      1  Jack F  Dublin  Dublin 9      Travel  07/07/2022      05:00
# 5      1  Jack F  Dublin  Dublin 9      Travel  07/08/2022      07:30
# 6      1  Jack F  Dublin  Dublin 9         Lab      08-Jul      09:00
# 7      1  Jack F  Dublin  Dublin 9       Sport  07/08/2022      11:00
# 8      1  Jack F  Dublin  Dublin 9  Group work  07/08/2022      13:00
# 9      1  Jack F  Dublin  Dublin 9      Travel  07/07/2022       7;30
# 10     1  Jack F  Dublin  Dublin 9      Travel  07/08/2022      07:30
# 11     1  Jack F  Dublin  Dublin 9         Lab      08-Jul      09:00
#
#     Duration Priority Completed Transport Distance  \
# ...

# %%
#  Lets extract those rows that are duplicated. As you can see from the result, rows 9 and 10 are duplicated.
duplicate = data.duplicated()
duplicate.head(15)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11    False
# dtype: bool

# %%
# Now, lets remove the duplicated rows. Row 9 and 10 are removed from the data because they are duplicated.
clean_data = data.drop_duplicates()
clean_data.head(15)
# Out:
#     Code    Name  County      City    Activity        Date Start Time  \
# 0      1  Jack F  Dublin  Dublin 9      Travel  07/07/2022       7;30
# 1      1  Jack F  Dublin  Dublin 9     Lecture  07/07/2022      09:00
# 2      1  Jack F  Dublin  Dublin 9     Lecture  07/07/2022      11:00
# 3      1  Jack F  Dublin  Dublin 9       Study  07/07/2022      01:00
# 4      1  Jack F  Dublin  Dublin 9      Travel  07/07/2022      05:00
# 5      1  Jack F  Dublin  Dublin 9      Travel  07/08/2022      07:30
# 6      1  Jack F  Dublin  Dublin 9         Lab      08-Jul      09:00
# 7      1  Jack F  Dublin  Dublin 9       Sport  07/08/2022      11:00
# 8      1  Jack F  Dublin  Dublin 9  Group work  07/08/2022      13:00
# 11     1  Jack F  Dublin  Dublin 9         Lab      08-Jul      09:00
#
#     Duration Priority Completed Transport Distance  \
# 0         30     High       Yes       Bus        5
# 1        120     High       Yes       NaN      NaN
# ...
